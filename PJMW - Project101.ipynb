# %% [markdown]
# # P-219 => Hourly Energy Consumption Forecast
#
#     The hourly power consumption data comes from PJM's website and are in megawatts (MW).
#
#     ● Build model, split the last year into a test set and train model on remaining data.
#     ● Forecast for next 30 days using model build.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import datetime as dt
warnings.filterwarnings('ignore')

# %%
plt.rcParams['figure.figsize'] = (10,5)
plt.rcParams['figure.dpi'] = 200
sns.set_style('darkgrid')

# %%
# Importing data set
df = pd.read_excel(r"C:\Users\rohit\Downloads\Project\PJMW_MW_Hourly.xlsx", index_col=0)
df.index = pd.to_datetime(df.index)
df
# Out:
#                      PJMW_MW
# Datetime
# 2002-12-31 01:00:00   5077.0
# 2002-12-31 02:00:00   4939.0
# 2002-12-31 03:00:00   4885.0
# 2002-12-31 04:00:00   4857.0
# 2002-12-31 05:00:00   4930.0
# ...                      ...
# 2018-01-01 20:00:00   8401.0
# 2018-01-01 21:00:00   8373.0
# 2018-01-01 22:00:00   8238.0
# 2018-01-01 23:00:00   7958.0
# 2018-01-02 00:00:00   7691.0
#
# [143206 rows x 1 columns]

# %% [markdown]
# ## Data preprocessing and EDA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 143206 entries, 2002-12-31 01:00:00 to 2018-01-02 00:00:00
# Data columns (total 1 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   PJMW_MW  143206 non-null  float64
# dtypes: float64(1)
# memory usage: 2.2 MB

# %%
df.describe(include='all')
# Out:
#              PJMW_MW
# count  143206.000000
# mean     5602.375089
# std       979.142872
# min       487.000000
# 25%      4907.000000
# 50%      5530.000000
# 75%      6252.000000
# max      9594.000000

# %%
df.isna().sum()
# Out:
# PJMW_MW    0
# dtype: int64

# %%
import dtale

# %%
dtale.show(df)
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://Rohit:40000/dtale/iframe/2"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
df[df.duplicated()]
# Out:
#                      PJMW_MW
# Datetime
# 2002-12-30 23:00:00   5885.0
# 2002-12-28 09:00:00   6167.0
# 2002-12-28 13:00:00   6178.0
# 2002-12-28 16:00:00   5962.0
# 2002-12-28 22:00:00   6167.0
# ...                      ...
# 2018-01-01 19:00:00   8328.0
# 2018-01-01 21:00:00   8373.0
# 2018-01-01 22:00:00   8238.0
# 2018-01-01 23:00:00   7958.0
# 2018-01-02 00:00:00   7691.0
#
# [137863 rows x 1 columns]

# %%
plt.plot(df)
plt.xlabel('Datetime')
plt.ylabel('PJMW (in MW)')
# Out:
# Text(0, 0.5, 'PJMW (in MW)')

# %%
sns.distplot(df, bins=30)
# Out:
# <AxesSubplot: ylabel='Density'>

# %%
sns.histplot(df, bins=30)
# Out:
# <AxesSubplot: ylabel='Count'>

# %% [markdown]
# ### From histogram we can say that the data is normally distributed

# %%
sns.kdeplot(df.index)
# Out:
# <AxesSubplot: xlabel='Datetime', ylabel='Density'>

# %%
sns.heatmap(df)
# Out:
# <AxesSubplot: ylabel='Datetime'>

# %%
from pandas_profiling import ProfileReport

# %%
profile = ProfileReport(df)
profile.to_file('profile_report.html')
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
sns.boxplot(df['PJMW_MW'])
# Out:
# <AxesSubplot: xlabel='PJMW_MW'>

# %%
sns.boxplot(x=df.index.year, y=df['PJMW_MW'])
# Out:
# <AxesSubplot: xlabel='Datetime', ylabel='PJMW_MW'>

# %%
sns.boxplot(x=df.index.month_name(), y=df['PJMW_MW'])
# Out:
# <AxesSubplot: xlabel='Datetime', ylabel='PJMW_MW'>

# %% [markdown]
# ### In above graph instead of using month we use month_name() because our datetime series starts form 'December' instead of 'January' and it gives numbers according to datetime series sequence ie. December will be numbered as 1 instead of 12

# %%
# Monthly usage across years
monthly_usage_across_years = pd.pivot_table(df, values='PJMW_MW', columns=df.index.month_name(), index=df.index.year)
monthly_usage_across_years
# Out:
# Datetime        April       August     December     February      January  \
# Datetime
# 2002      5171.318942  6063.909946  6154.673387          NaN          NaN
# 2003      5232.509040  6024.669355  6266.799731  6402.547619  6586.263441
# 2004      5426.936022  5910.219086  6395.706989  6393.234195  6828.658602
# 2005      5380.983310  6471.497312  6563.709677  6433.568452  6598.818548
# 2006      4788.084840  6017.083333  5692.561828  6041.986607  5753.059140
# 2007      5215.961111  6079.646505  6046.346774  6725.876488  6038.096774
# 2008      4959.263889  5458.784946  6015.278226  6279.462644  6268.275538
# 2009      4849.751389  5540.622312  6031.521505  6022.083333  6550.642473
# 2010      4738.938889  5838.908602  6477.201884  6378.889881  6406.479839
# 2011      4961.569444  5709.915323  5704.434140  6106.610119  6533.490591
# 2012      4752.937500  5659.037634  5711.481183  5833.787356  6116.665323
# 2013      4944.922222  5446.470430  6080.012097  6362.821429  6220.529570
# 2014      4977.568056  5482.196237  6047.541667  6616.827381  7009.864247
# 2015      4955.444444  5583.073925  5364.998656  7269.055060  6777.696237
# 2016      4937.476389  6255.744624  6129.709677  6226.278736  6508.473118
# 2017      4805.781944  5609.067204  6349.477151  5692.532738  6095.760753
# 2018      5281.277778  5874.346939          NaN  5979.610119  6869.909946
#
# Datetime         July         June        March          May     November  \
# Datetime
# 2002      6097.877688  5685.681944          NaN  5085.094086  5582.980556
# 2003      5820.044355  5398.618056  5641.485215  5026.915323  5445.623611
# 2004      5956.732527  5716.779167  5777.657258  5511.560484  5602.116667
# 2005      6391.413978  6156.520833  6218.537634  5253.323925  5779.622222
# 2006      5892.213710  5316.781944  5541.309140  4875.614247  5260.411111
# 2007      5560.966398  5508.394444  5599.539704  5034.049731  5433.479833
# 2008      5776.416667  5562.731944  5627.838493  4840.682796  5457.931850
# 2009      5105.278226  5059.287500  5337.670256  4572.251344  4955.984701
# 2010      6035.850806  5689.716667  5323.368775  4962.254032  5256.499305
# 2011      6097.427419  5480.983333  5562.510094  4947.189516  5157.801113
# 2012      5943.020161  5340.579167  5014.018843  5098.493280  5485.579972
# 2013      5824.797043  5365.340278  5883.000000  4973.587366  5614.906815
# 2014      5580.614247  5498.970833  6081.919246  4898.639785  5663.607490
# 2015      5781.505376  5506.200000  6017.460296  5152.038978  5053.233010
# 2016      5960.276882  5461.280556  5184.775236  4857.510753  5234.746186
# 2017      5842.966398  5477.659722  5680.520861  4901.551075  5473.181692
# 2018      5978.728495  5559.326389  5973.189771  5278.620968          NaN
#
# Datetime      October    September
# Datetime
# 2002      5311.936743  5419.641667
# 2003      5275.403769  5307.640278
# 2004      5313.002692  5562.062500
# 2005      5437.663526  5777.605556
# 2006      5027.837147  4910.723611
# 2007      5105.029570  5349.212500
# 2008      4986.365591  5144.813889
# 2009      4733.576613  4748.466667
# 2010      4732.794355  5064.072222
# 2011      4836.944892  5028.708333
# 2012      4805.700269  4973.606944
# 2013      4995.041667  5006.712500
# 2014      4890.766129  5178.868056
# 2015      4809.196237  5288.500000
# 2016      4758.688172  5421.413889
# 2017      4944.178763  5111.904167
# 2018              NaN          NaN

# %%
monthly_usage_across_years.plot()
plt.legend(bbox_to_anchor=(1, 1), loc='upper left')
plt.xlabel('Years')
plt.ylabel('PJMW (in MW)')
# Out:
# Text(0, 0.5, 'PJMW (in MW)')

# %%
# Total monthly usage 
total_monthly_usage = monthly_usage_across_years.sum(axis=0, skipna=True)
total_monthly_usage
# Out:
# Datetime
# April         85380.725210
# August        99025.193713
# December      97031.454572
# February     100765.172157
# January      103162.684140
# July          99646.130376
# June          93784.852778
# March         90464.800822
# May           85269.377688
# November      86457.706132
# October       79964.126134
# September     83293.952778
# dtype: float64

# %%
total_monthly_usage.plot(marker='o', title='Monthly usage')
plt.xlabel('Month')
plt.ylabel('PJMW (in MW)')
# Out:
# Text(0, 0.5, 'PJMW (in MW)')

# %%
# Quarterly usage across years
quarterly_usage_over_years = pd.pivot_table(df, values='PJMW_MW', columns=df.index.quarter, index=df.index.year)
quarterly_usage_over_years
# Out:
# Datetime            1            2            3            4
# Datetime
# 2002              NaN  5311.644363  5865.268116  5684.454916
# 2003      6203.683796  5217.225836  5721.905797  5665.144087
# 2004      6331.863553  5551.373798  5812.362772  5772.311282
# 2005      6416.421759  5593.263857  6218.243659  5928.822836
# 2006      5770.011574  4992.291800  5614.238225  5327.795650
# 2007      6101.246410  5250.397894  5666.688859  5529.359311
# 2008      6053.864865  5117.813645  5463.431159  5486.849116
# 2009      5968.692450  4824.296245  5135.618659  5243.582238
# 2010      6025.149606  5128.456502  5652.605525  5491.016772
# 2011      6066.467809  5127.906136  5618.357337  5233.912551
# 2012      5651.182318  5064.382326  5531.217391  5332.539647
# 2013      6148.660954  5093.286630  5430.550725  5562.735841
# 2014      6568.185734  5122.571429  5416.447464  5532.622001
# 2015      6669.006021  5203.983974  5553.879982  5076.044364
# 2016      5967.971599  5082.918040  5884.120471  5375.835220
# 2017      5827.352941  5059.904762  5525.762681  5590.151200
# 2018      6284.201482  5372.037088  5972.278689          NaN

# %%
quarterly_usage_over_years.plot()
plt.xlabel('Years')
plt.ylabel('PJMW (in MW)')
# Out:
# Text(0, 0.5, 'PJMW (in MW)')

# %%
# Total quarterly usage
total_quarterly_usage = quarterly_usage_over_years.sum(axis=0, skipna=True)
total_quarterly_usage
# Out:
# Datetime
# 1    98053.962873
# 2    88113.754324
# 3    96082.977511
# 4    87833.177033
# dtype: float64

# %%
total_quarterly_usage.plot(marker='o', title='Quarterly usage')
plt.xlabel('Quarter')
plt.ylabel('PJMW (in MW)')
# Out:
# Text(0, 0.5, 'PJMW (in MW)')

# %%
# Plotting of Empirical Cumulative Distribution Function
from statsmodels.distributions.empirical_distribution import ECDF
cdf = ECDF(df['PJMW_MW'])
plt.plot(cdf.x, cdf.y)
plt.xlabel('PJMW (in MW)')
# Out:
# Text(0.5, 0, 'PJMW (in MW)')

# %% [markdown]
# ### From above graph we ca see that around 60% of PJMW (power usage) is 5600 MW or less

# %%
# Average usage per year
average_year = df.groupby(df.index.year)["PJMW_MW"].mean()
average_year
# Out:
# Datetime
# 2002    5621.663180
# 2003    5700.628226
# 2004    5866.616602
# 2005    6038.406029
# 2006    5425.448847
# 2007    5635.396780
# 2008    5530.132544
# 2009    5290.557433
# 2010    5573.025351
# 2011    5509.640215
# 2012    5395.010818
# 2013    5556.783626
# 2014    5656.334132
# 2015    5620.985616
# 2016    5577.929531
# 2017    5500.184361
# 2018    5848.157516
# Name: PJMW_MW, dtype: float64

# %%
average_year.plot(marker='o', title='Average Usage over Years')
plt.xlabel('Years')
plt.ylabel('PJMW (in MW)')
# Out:
# Text(0, 0.5, 'PJMW (in MW)')

# %%
# Average usage per month
average_month = df.groupby(df.index.month_name())["PJMW_MW"].mean()
average_month
# Out:
# Datetime
# April        5022.310855
# August       5822.142809
# December     6064.431236
# February     6296.808813
# January      6447.667759
# July         5861.537081
# June         5516.756046
# March        5654.097376
# May          5015.845746
# November     5403.630372
# October      4997.642155
# September    5205.872049
# Name: PJMW_MW, dtype: float64

# %%
average_month.plot(marker='o', title='Average Usage over Months')
plt.xlabel('Month')
plt.ylabel('PJMW (in MW)')
# Out:
# Text(0, 0.5, 'PJMW (in MW)')

# %%
# Percentage change of power usage per year 
pct_change_year = df.groupby(df.index.year)["PJMW_MW"].sum().pct_change()
pct_change_year
# Out:
# Datetime
# 2002         NaN
# 2003    0.346221
# 2004    0.031938
# 2005    0.026470
# 2006   -0.101510
# 2007    0.038697
# 2008   -0.015990
# 2009   -0.045936
# 2010    0.053271
# 2011   -0.011261
# 2012   -0.018122
# 2013    0.027171
# 2014    0.018148
# 2015   -0.006249
# 2016   -0.004941
# 2017   -0.016632
# 2018   -0.376606
# Name: PJMW_MW, dtype: float64

# %%
pct_change_year.plot(marker='o', title='Percentage change over Years')
plt.xlabel('Years')
plt.ylabel('Percentage')
# Out:
# Text(0, 0.5, 'Percentage')

# %%
# Percentage change of power usage per month
pct_change_month = df.groupby(df.index.month_name())["PJMW_MW"].sum().pct_change()
pct_change_month
# Out:
# Datetime
# April             NaN
# August       0.132629
# December     0.037258
# February    -0.053711
# January      0.123635
# July        -0.034087
# June        -0.089182
# March       -0.004244
# May         -0.056487
# November    -0.019023
# October     -0.044456
# September    0.008487
# Name: PJMW_MW, dtype: float64

# %%
pct_change_month.plot(marker='o', title='Percentage change over Months')
plt.xlabel('Month')
plt.ylabel('Percentage')
# Out:
# Text(0, 0.5, 'Percentage')

# %% [markdown]
# ### Decomposing the Time Series and plotting the different components

# %% [markdown]
# #### Assuming Additive Decomposition

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
add_decomposition = seasonal_decompose(df, model='additive', period=71603)
add_decomposition.plot();

# %% [markdown]
# #### Assuming Multiplicative Decomposition

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
mul_decomposition = seasonal_decompose(df, model='multiplicative', period=71603)
mul_decomposition.plot();

# %% [markdown]
# #### In the multiplicative model, We observe that the trend and seasonality are clearly separated and the scale of noise is small. In the additive model, there are outliers present in the residual. So the series is multiplicative.
